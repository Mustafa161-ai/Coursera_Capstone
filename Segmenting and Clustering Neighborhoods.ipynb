# %% [markdown]
# Segmenting and Clustering Neighborhoods in Toronto - PART 1

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
#
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# !conda install -c conda-forge bs4 --yes
from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
# Import Data from Wikipedia
URL = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

wikiRequest = requests.get(URL).text
soup = BeautifulSoup(wikiRequest, 'html.parser')

PostalCodesTable = soup.find('table', class_='wikitable')

# %%
# Parse the data into the Dataframe
postalCodesdf = pd.DataFrame()

for items in soup.find('table', class_='wikitable').find_all('tr')[1::1]:
    data = items.find_all(['td'])
    try:
        postalCode = data[0].text
        borough = data[1].text
        neighborhood = data[2].text
        postalCode= postalCode.replace('\n','')
        borough=borough.replace('\n', '')
        neighborhood=neighborhood.replace('\n', '')
        neighborhood=neighborhood.replace(' / ', ', ')
        if(neighborhood=='Not assigned'):
            neighborhood=borough
    except IndexError:pass
    
    if(borough!='Not assigned'):
        postalCodesRow = pd.Series([postalCode,borough,neighborhood])
        postalCodes = pd.DataFrame([postalCodesRow])
        postalCodesdf = pd.concat([postalCodesdf, postalCodes], ignore_index=True)
        
postalCodesdf = postalCodesdf.rename(columns={0:'Postal Code',1:'Borough',2:'Neighborhood'})
postalCodesdf.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.
postalCodesdf.shape
# Out:
# (103, 3)

# %% [markdown]
# Segmenting and Clustering Neighborhoods in Toronto - PART 2

# %%
# Add location Coordinates of all the Postal Codes
geodf = pd.read_csv('http://cocl.us/Geospatial_data', names=['Postal Code','Latitude','Longittude'],skiprows=1)
geodf.head()
postalcCodesdf=pd.merge(postalCodesdf, geodf, on='Postal Code')
postalcCodesdf.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longittude
# 0  43.753259  -79.329656
# 1  43.725882  -79.315572
# 2  43.654260  -79.360636
# 3  43.718518  -79.464763
# 4  43.662301  -79.389494

# %%
address = 'Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
#Working with only Downtown Toronto
torontodf = postalcCodesdf[postalcCodesdf['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
torontodf.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M5E  Downtown Toronto                                  Berczy Park
#
#     Latitude  Longittude
# 0  43.654260  -79.360636
# 1  43.662301  -79.389494
# 2  43.657162  -79.378937
# 3  43.651494  -79.375418
# 4  43.644771  -79.373306

# %%
address = 'Downtown Toronto,Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %%
# Define Foursquare Credentials and Version
LIMIT =100
radius = 500
CLIENT_ID = '0IQXIUQBL5CK51XCMZUB0QLIDVRAWBUD4YTIJGFWZOGGO1FL' # your Foursquare ID
CLIENT_SECRET = '2JPLPR2TXS5ILNTAULTR3L5SDMHDHCQZWEJOP3EJ1CTQUMYT' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 0IQXIUQBL5CK51XCMZUB0QLIDVRAWBUD4YTIJGFWZOGGO1FL
# CLIENT_SECRET:2JPLPR2TXS5ILNTAULTR3L5SDMHDHCQZWEJOP3EJ1CTQUMYT

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here

downtownVenues = getNearbyVenues(names=torontodf['Neighborhood'],
                                   latitudes=torontodf['Latitude'],
                                   longitudes=torontodf['Longittude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley

# %%
downtownVenues.head()
# Out:
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4      Morning Glory Cafe       43.653947       -79.361149
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4       Breakfast Spot

# %%
print('There are {} uniques categories.'.format(len(downtownVenues['Venue Category'].unique())))
# Out:
# There are 202 uniques categories.

# %%
# one hot encoding
downtownOnehot = pd.get_dummies(downtownVenues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
downtownOnehot['Neighborhood'] = downtownVenues['Neighborhood'] 

downtownOnehot.set_index('Neighborhood', inplace=True)
# # move neighborhood column to the first column
# fixed_columns = [downtownOnehot.columns[-1]] + list(downtownOnehot.columns[:-1])
# downtownOnehot = downtownOnehot[fixed_columns]

downtownOnehot.head()
# Out:
#                            Airport  Airport Food Court  Airport Gate  \
# Neighborhood
# Regent Park, Harbourfront        0                   0             0
# Regent Park, Harbourfront        0                   0             0
# Regent Park, Harbourfront        0                   0             0
# Regent Park, Harbourfront        0                   0             0
# Regent Park, Harbourfront        0                   0             0
#
#                            Airport Lounge  Airport Service  Airport Terminal  \
# Neighborhood
# Regent Park, Harbourfront               0                0                 0
# Regent Park, Harbourfront               0                0                 0
# Regent Park, Harbourfront               0                0                 0
# Regent Park, Harbourfront               0                0                 0
# Regent Park, Harbourfront               0                0                 0
#
#                            American Restaurant  Antique Shop  Aquarium  \
# Neighborhood
# Regent Park, Harbourfront                    0             0         0
# Regent Park, Harbourfront                    0             0         0
# Regent Park, Harbourfront                    0             0         0
# Regent Park, Harbourfront                    0             0         0
# Regent Park, Harbourfront                    0             0         0
#
#                            Art Gallery  Arts & Crafts Store  Asian Restaurant  \
# Neighborhood
# Regent Park, Harbourfront            0                    0                 0
# Regent Park, Harbourfront            0                    0                 0
# Regent Park, Harbourfront            0                    0                 0
# Regent Park, Harbourfront            0                    0                 0
# Regent Park, Harbourfront            0                    0                 0
#
#                            Athletics & Sports  BBQ Joint  Baby Store  \
# Neighborhood
# Regent Park, Harbourfront                   0          0           0
# Regent Park, Harbourfront                   0          0           0
# Regent Park, Harbourfront                   0          0           0
# Regent Park, Harbourfront                   0          0           0
# Regent Park, Harbourfront                   0          0           0
#
#                            Bagel Shop  Bakery  Bank  Bar  Baseball Stadium  \
# Neighborhood
# Regent Park, Harbourfront           0       1     0    0                 0
# Regent Park, Harbourfront           0       0     0    0                 0
# Regent Park, Harbourfront           0       0     0    0                 0
# Regent Park, Harbourfront           0       0     0    0                 0
# Regent Park, Harbourfront           0       0     0    0                 0
#
#                            Basketball Stadium  Beach  Bed & Breakfast  \
# Neighborhood
# Regent Park, Harbourfront                   0      0                0
# Regent Park, Harbourfront                   0      0                0
# Regent Park, Harbourfront                   0      0                0
# Regent Park, Harbourfront                   0      0                0
# Regent Park, Harbourfront                   0      0                0
#
#                            Beer Bar  Beer Store  Belgian Restaurant  Bistro  \
# Neighborhood
# Regent Park, Harbourfront         0           0                   0       0
# Regent Park, Harbourfront         0           0                   0       0
# Regent Park, Harbourfront         0           0                   0       0
# Regent Park, Harbourfront         0           0                   0       0
# Regent Park, Harbourfront         0           0                   0       0
#
#                            Boat or Ferry  Bookstore  Boutique  \
# Neighborhood
# Regent Park, Harbourfront              0          0         0
# Regent Park, Harbourfront              0          0         0
# Regent Park, Harbourfront              0          0         0
# Regent Park, Harbourfront              0          0         0
# Regent Park, Harbourfront              0          0         0
#
#                            Brazilian Restaurant  Breakfast Spot  Brewery  \
# Neighborhood
# Regent Park, Harbourfront                     0               0        0
# Regent Park, Harbourfront                     0               0        0
# Regent Park, Harbourfront                     0               0        0
# Regent Park, Harbourfront                     0               0        0
# Regent Park, Harbourfront                     0               1        0
#
#                            Bubble Tea Shop  Building  Burger Joint  \
# Neighborhood
# Regent Park, Harbourfront                0         0             0
# Regent Park, Harbourfront                0         0             0
# Regent Park, Harbourfront                0         0             0
# Regent Park, Harbourfront                0         0             0
# Regent Park, Harbourfront                0         0             0
#
#                            Burrito Place  Butcher  Café  Candy Store  \
# Neighborhood
# Regent Park, Harbourfront              0        0     0            0
# Regent Park, Harbourfront              0        0     0            0
# Regent Park, Harbourfront              0        0     0            0
# Regent Park, Harbourfront              0        0     0            0
# Regent Park, Harbourfront              0        0     0            0
#
#                            Caribbean Restaurant  Cheese Shop  \
# Neighborhood
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
#
#                            Chinese Restaurant  Chocolate Shop  Church  \
# Neighborhood
# Regent Park, Harbourfront                   0               0       0
# Regent Park, Harbourfront                   0               0       0
# Regent Park, Harbourfront                   0               0       0
# Regent Park, Harbourfront                   0               0       0
# Regent Park, Harbourfront                   0               0       0
#
#                            Clothing Store  Cocktail Bar  Coffee Shop  \
# Neighborhood
# Regent Park, Harbourfront               0             0            0
# Regent Park, Harbourfront               0             0            1
# Regent Park, Harbourfront               0             0            0
# Regent Park, Harbourfront               0             0            0
# Regent Park, Harbourfront               0             0            0
#
#                            College Arts Building  College Auditorium  \
# Neighborhood
# Regent Park, Harbourfront                      0                   0
# Regent Park, Harbourfront                      0                   0
# Regent Park, Harbourfront                      0                   0
# Regent Park, Harbourfront                      0                   0
# Regent Park, Harbourfront                      0                   0
#
#                            College Gym  College Rec Center  \
# Neighborhood
# Regent Park, Harbourfront            0                   0
# Regent Park, Harbourfront            0                   0
# Regent Park, Harbourfront            0                   0
# Regent Park, Harbourfront            0                   0
# Regent Park, Harbourfront            0                   0
#
#                            Colombian Restaurant  Comfort Food Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                     0                        0
# Regent Park, Harbourfront                     0                        0
# Regent Park, Harbourfront                     0                        0
# Regent Park, Harbourfront                     0                        0
# Regent Park, Harbourfront                     0                        0
#
#                            Comic Shop  Concert Hall  Cosmetics Shop  Creperie  \
# Neighborhood
# Regent Park, Harbourfront           0             0               0         0
# Regent Park, Harbourfront           0             0               0         0
# Regent Park, Harbourfront           0             0               0         0
# Regent Park, Harbourfront           0             0               0         0
# Regent Park, Harbourfront           0             0               0         0
#
#                            Cupcake Shop  Dance Studio  Deli / Bodega  \
# Neighborhood
# Regent Park, Harbourfront             0             0              0
# Regent Park, Harbourfront             0             0              0
# Regent Park, Harbourfront             0             0              0
# Regent Park, Harbourfront             0             0              0
# Regent Park, Harbourfront             0             0              0
#
#                            Department Store  Dessert Shop  Diner  \
# Neighborhood
# Regent Park, Harbourfront                 0             0      0
# Regent Park, Harbourfront                 0             0      0
# Regent Park, Harbourfront                 0             0      0
# Regent Park, Harbourfront                 0             0      0
# Regent Park, Harbourfront                 0             0      0
#
#                            Discount Store  Distribution Center  Dog Run  \
# Neighborhood
# Regent Park, Harbourfront               0                    0        0
# Regent Park, Harbourfront               0                    0        0
# Regent Park, Harbourfront               0                    1        0
# Regent Park, Harbourfront               0                    0        0
# Regent Park, Harbourfront               0                    0        0
#
#                            Doner Restaurant  Donut Shop  Dumpling Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                 0           0                    0
# Regent Park, Harbourfront                 0           0                    0
# Regent Park, Harbourfront                 0           0                    0
# Regent Park, Harbourfront                 0           0                    0
# Regent Park, Harbourfront                 0           0                    0
#
#                            Eastern European Restaurant  Electronics Store  \
# Neighborhood
# Regent Park, Harbourfront                            0                  0
# Regent Park, Harbourfront                            0                  0
# Regent Park, Harbourfront                            0                  0
# Regent Park, Harbourfront                            0                  0
# Regent Park, Harbourfront                            0                  0
#
#                            Ethiopian Restaurant  Event Space  \
# Neighborhood
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
# Regent Park, Harbourfront                     0            0
#
#                            Falafel Restaurant  Farmers Market  \
# Neighborhood
# Regent Park, Harbourfront                   0               0
# Regent Park, Harbourfront                   0               0
# Regent Park, Harbourfront                   0               0
# Regent Park, Harbourfront                   0               0
# Regent Park, Harbourfront                   0               0
#
#                            Fast Food Restaurant  Filipino Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                     0                    0
# Regent Park, Harbourfront                     0                    0
# Regent Park, Harbourfront                     0                    0
# Regent Park, Harbourfront                     0                    0
# Regent Park, Harbourfront                     0                    0
#
#                            Fish Market  Flower Shop  Food & Drink Shop  \
# Neighborhood
# Regent Park, Harbourfront            0            0                  0
# Regent Park, Harbourfront            0            0                  0
# Regent Park, Harbourfront            0            0                  0
# Regent Park, Harbourfront            0            0                  0
# Regent Park, Harbourfront            0            0                  0
#
#                            Food Court  Food Truck  Fountain  \
# Neighborhood
# Regent Park, Harbourfront           0           0         0
# Regent Park, Harbourfront           0           0         0
# Regent Park, Harbourfront           0           0         0
# Regent Park, Harbourfront           0           0         0
# Regent Park, Harbourfront           0           0         0
#
#                            French Restaurant  Fried Chicken Joint  \
# Neighborhood
# Regent Park, Harbourfront                  0                    0
# Regent Park, Harbourfront                  0                    0
# Regent Park, Harbourfront                  0                    0
# Regent Park, Harbourfront                  0                    0
# Regent Park, Harbourfront                  0                    0
#
#                            Furniture / Home Store  Gaming Cafe  Gas Station  \
# Neighborhood
# Regent Park, Harbourfront                       0            0            0
# Regent Park, Harbourfront                       0            0            0
# Regent Park, Harbourfront                       0            0            0
# Regent Park, Harbourfront                       0            0            0
# Regent Park, Harbourfront                       0            0            0
#
#                            Gastropub  Gay Bar  General Entertainment  \
# Neighborhood
# Regent Park, Harbourfront          0        0                      0
# Regent Park, Harbourfront          0        0                      0
# Regent Park, Harbourfront          0        0                      0
# Regent Park, Harbourfront          0        0                      0
# Regent Park, Harbourfront          0        0                      0
#
#                            General Travel  German Restaurant  Gift Shop  \
# Neighborhood
# Regent Park, Harbourfront               0                  0          0
# Regent Park, Harbourfront               0                  0          0
# Regent Park, Harbourfront               0                  0          0
# Regent Park, Harbourfront               0                  0          0
# Regent Park, Harbourfront               0                  0          0
#
#                            Gluten-free Restaurant  Gourmet Shop  \
# Neighborhood
# Regent Park, Harbourfront                       0             0
# Regent Park, Harbourfront                       0             0
# Regent Park, Harbourfront                       0             0
# Regent Park, Harbourfront                       0             0
# Regent Park, Harbourfront                       0             0
#
#                            Greek Restaurant  Grocery Store  Gym  \
# Neighborhood
# Regent Park, Harbourfront                 0              0    0
# Regent Park, Harbourfront                 0              0    0
# Regent Park, Harbourfront                 0              0    0
# Regent Park, Harbourfront                 0              0    0
# Regent Park, Harbourfront                 0              0    0
#
#                            Gym / Fitness Center  Harbor / Marina  \
# Neighborhood
# Regent Park, Harbourfront                     0                0
# Regent Park, Harbourfront                     0                0
# Regent Park, Harbourfront                     0                0
# Regent Park, Harbourfront                     0                0
# Regent Park, Harbourfront                     0                0
#
#                            Health & Beauty Service  Health Food Store  \
# Neighborhood
# Regent Park, Harbourfront                        0                  0
# Regent Park, Harbourfront                        0                  0
# Regent Park, Harbourfront                        0                  0
# Regent Park, Harbourfront                        0                  0
# Regent Park, Harbourfront                        0                  0
#
#                            Historic Site  History Museum  Hobby Shop  \
# Neighborhood
# Regent Park, Harbourfront              0               0           0
# Regent Park, Harbourfront              0               0           0
# Regent Park, Harbourfront              0               0           0
# Regent Park, Harbourfront              0               0           0
# Regent Park, Harbourfront              0               0           0
#
#                            Hospital  Hostel  Hotel  Hotel Bar  IT Services  \
# Neighborhood
# Regent Park, Harbourfront         0       0      0          0            0
# Regent Park, Harbourfront         0       0      0          0            0
# Regent Park, Harbourfront         0       0      0          0            0
# Regent Park, Harbourfront         0       0      0          0            0
# Regent Park, Harbourfront         0       0      0          0            0
#
#                            Ice Cream Shop  Indian Restaurant  \
# Neighborhood
# Regent Park, Harbourfront               0                  0
# Regent Park, Harbourfront               0                  0
# Regent Park, Harbourfront               0                  0
# Regent Park, Harbourfront               0                  0
# Regent Park, Harbourfront               0                  0
#
#                            Indie Movie Theater  Intersection  Irish Pub  \
# Neighborhood
# Regent Park, Harbourfront                    0             0          0
# Regent Park, Harbourfront                    0             0          0
# Regent Park, Harbourfront                    0             0          0
# Regent Park, Harbourfront                    0             0          0
# Regent Park, Harbourfront                    0             0          0
#
#                            Italian Restaurant  Japanese Restaurant  Jazz Club  \
# Neighborhood
# Regent Park, Harbourfront                   0                    0          0
# Regent Park, Harbourfront                   0                    0          0
# Regent Park, Harbourfront                   0                    0          0
# Regent Park, Harbourfront                   0                    0          0
# Regent Park, Harbourfront                   0                    0          0
#
#                            Jewelry Store  Juice Bar  Korean Restaurant  Lake  \
# Neighborhood
# Regent Park, Harbourfront              0          0                  0     0
# Regent Park, Harbourfront              0          0                  0     0
# Regent Park, Harbourfront              0          0                  0     0
# Regent Park, Harbourfront              0          0                  0     0
# Regent Park, Harbourfront              0          0                  0     0
#
#                            Latin American Restaurant  Lingerie Store  \
# Neighborhood
# Regent Park, Harbourfront                          0               0
# Regent Park, Harbourfront                          0               0
# Regent Park, Harbourfront                          0               0
# Regent Park, Harbourfront                          0               0
# Regent Park, Harbourfront                          0               0
#
#                            Liquor Store  Lounge  Market  \
# Neighborhood
# Regent Park, Harbourfront             0       0       0
# Regent Park, Harbourfront             0       0       0
# Regent Park, Harbourfront             0       0       0
# Regent Park, Harbourfront             0       0       0
# Regent Park, Harbourfront             0       0       0
#
#                            Mediterranean Restaurant  Men's Store  \
# Neighborhood
# Regent Park, Harbourfront                         0            0
# Regent Park, Harbourfront                         0            0
# Regent Park, Harbourfront                         0            0
# Regent Park, Harbourfront                         0            0
# Regent Park, Harbourfront                         0            0
#
#                            Mexican Restaurant  Middle Eastern Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                   0                          0
# Regent Park, Harbourfront                   0                          0
# Regent Park, Harbourfront                   0                          0
# Regent Park, Harbourfront                   0                          0
# Regent Park, Harbourfront                   0                          0
#
#                            Miscellaneous Shop  Modern European Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                   0                           0
# Regent Park, Harbourfront                   0                           0
# Regent Park, Harbourfront                   0                           0
# Regent Park, Harbourfront                   0                           0
# Regent Park, Harbourfront                   0                           0
#
#                            Molecular Gastronomy Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                                0
# Regent Park, Harbourfront                                0
# Regent Park, Harbourfront                                0
# Regent Park, Harbourfront                                0
# Regent Park, Harbourfront                                0
#
#                            Monument / Landmark  Moroccan Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                    0                    0
# Regent Park, Harbourfront                    0                    0
# Regent Park, Harbourfront                    0                    0
# Regent Park, Harbourfront                    0                    0
# Regent Park, Harbourfront                    0                    0
#
#                            Movie Theater  Museum  Music Venue  \
# Neighborhood
# Regent Park, Harbourfront              0       0            0
# Regent Park, Harbourfront              0       0            0
# Regent Park, Harbourfront              0       0            0
# Regent Park, Harbourfront              0       0            0
# Regent Park, Harbourfront              0       0            0
#
#                            New American Restaurant  Nightclub  Noodle House  \
# Neighborhood
# Regent Park, Harbourfront                        0          0             0
# Regent Park, Harbourfront                        0          0             0
# Regent Park, Harbourfront                        0          0             0
# Regent Park, Harbourfront                        0          0             0
# Regent Park, Harbourfront                        0          0             0
#
#                            Office  Opera House  Optical Shop  Organic Grocery  \
# Neighborhood
# Regent Park, Harbourfront       0            0             0                0
# Regent Park, Harbourfront       0            0             0                0
# Regent Park, Harbourfront       0            0             0                0
# Regent Park, Harbourfront       0            0             0                0
# Regent Park, Harbourfront       0            0             0                0
#
#                            Other Great Outdoors  Park  Performing Arts Venue  \
# Neighborhood
# Regent Park, Harbourfront                     0     0                      0
# Regent Park, Harbourfront                     0     0                      0
# Regent Park, Harbourfront                     0     0                      0
# Regent Park, Harbourfront                     0     0                      0
# Regent Park, Harbourfront                     0     0                      0
#
#                            Pet Store  Pharmacy  Pizza Place  Playground  \
# Neighborhood
# Regent Park, Harbourfront          0         0            0           0
# Regent Park, Harbourfront          0         0            0           0
# Regent Park, Harbourfront          0         0            0           0
# Regent Park, Harbourfront          0         0            0           0
# Regent Park, Harbourfront          0         0            0           0
#
#                            Plaza  Poke Place  Poutine Place  Pub  \
# Neighborhood
# Regent Park, Harbourfront      0           0              0    0
# Regent Park, Harbourfront      0           0              0    0
# Regent Park, Harbourfront      0           0              0    0
# Regent Park, Harbourfront      0           0              0    0
# Regent Park, Harbourfront      0           0              0    0
#
#                            Ramen Restaurant  Record Shop  Restaurant  \
# Neighborhood
# Regent Park, Harbourfront                 0            0           0
# Regent Park, Harbourfront                 0            0           0
# Regent Park, Harbourfront                 0            0           0
# Regent Park, Harbourfront                 0            0           0
# Regent Park, Harbourfront                 0            0           0
#
#                            Roof Deck  Sake Bar  Salad Place  \
# Neighborhood
# Regent Park, Harbourfront          0         0            0
# Regent Park, Harbourfront          0         0            0
# Regent Park, Harbourfront          0         0            0
# Regent Park, Harbourfront          0         0            0
# Regent Park, Harbourfront          0         0            0
#
#                            Salon / Barbershop  Sandwich Place  Scenic Lookout  \
# Neighborhood
# Regent Park, Harbourfront                   0               0               0
# Regent Park, Harbourfront                   0               0               0
# Regent Park, Harbourfront                   0               0               0
# Regent Park, Harbourfront                   0               0               0
# Regent Park, Harbourfront                   0               0               0
#
#                            Sculpture Garden  Seafood Restaurant  Shoe Store  \
# Neighborhood
# Regent Park, Harbourfront                 0                   0           0
# Regent Park, Harbourfront                 0                   0           0
# Regent Park, Harbourfront                 0                   0           0
# Regent Park, Harbourfront                 0                   0           0
# Regent Park, Harbourfront                 0                   0           0
#
#                            Shopping Mall  Skating Rink  Smoke Shop  \
# Neighborhood
# Regent Park, Harbourfront              0             0           0
# Regent Park, Harbourfront              0             0           0
# Regent Park, Harbourfront              0             0           0
# Regent Park, Harbourfront              0             0           0
# Regent Park, Harbourfront              0             0           0
#
#                            Snack Place  Soup Place  Spa  Speakeasy  \
# Neighborhood
# Regent Park, Harbourfront            0           0    0          0
# Regent Park, Harbourfront            0           0    0          0
# Regent Park, Harbourfront            0           0    0          0
# Regent Park, Harbourfront            0           0    1          0
# Regent Park, Harbourfront            0           0    0          0
#
#                            Sporting Goods Shop  Sports Bar  Steakhouse  \
# Neighborhood
# Regent Park, Harbourfront                    0           0           0
# Regent Park, Harbourfront                    0           0           0
# Regent Park, Harbourfront                    0           0           0
# Regent Park, Harbourfront                    0           0           0
# Regent Park, Harbourfront                    0           0           0
#
#                            Strip Club  Supermarket  Sushi Restaurant  \
# Neighborhood
# Regent Park, Harbourfront           0            0                 0
# Regent Park, Harbourfront           0            0                 0
# Regent Park, Harbourfront           0            0                 0
# Regent Park, Harbourfront           0            0                 0
# Regent Park, Harbourfront           0            0                 0
#
#                            Taco Place  Tailor Shop  Taiwanese Restaurant  \
# Neighborhood
# Regent Park, Harbourfront           0            0                     0
# Regent Park, Harbourfront           0            0                     0
# Regent Park, Harbourfront           0            0                     0
# Regent Park, Harbourfront           0            0                     0
# Regent Park, Harbourfront           0            0                     0
#
#                            Tanning Salon  Tea Room  Thai Restaurant  Theater  \
# Neighborhood
# Regent Park, Harbourfront              0         0                0        0
# Regent Park, Harbourfront              0         0                0        0
# Regent Park, Harbourfront              0         0                0        0
# Regent Park, Harbourfront              0         0                0        0
# Regent Park, Harbourfront              0         0                0        0
#
#                            Theme Restaurant  Trail  Train Station  \
# Neighborhood
# Regent Park, Harbourfront                 0      0              0
# Regent Park, Harbourfront                 0      0              0
# Regent Park, Harbourfront                 0      0              0
# Regent Park, Harbourfront                 0      0              0
# Regent Park, Harbourfront                 0      0              0
#
#                            Vegetarian / Vegan Restaurant  Video Game Store  \
# Neighborhood
# Regent Park, Harbourfront                              0                 0
# Regent Park, Harbourfront                              0                 0
# Regent Park, Harbourfront                              0                 0
# Regent Park, Harbourfront                              0                 0
# Regent Park, Harbourfront                              0                 0
#
#                            Vietnamese Restaurant  Wine Bar  Wine Shop  \
# Neighborhood
# Regent Park, Harbourfront                      0         0          0
# Regent Park, Harbourfront                      0         0          0
# Regent Park, Harbourfront                      0         0          0
# Regent Park, Harbourfront                      0         0          0
# Regent Park, Harbourfront                      0         0          0
#
#                            Women's Store  Yoga Studio
# Neighborhood
# Regent Park, Harbourfront              0            0
# Regent Park, Harbourfront              0            0
# Regent Park, Harbourfront              0            0
# Regent Park, Harbourfront              0            0
# Regent Park, Harbourfront              0            0

# %%
downtownOnehot.shape
downtownGrouped = downtownOnehot.groupby('Neighborhood').mean().reset_index()
downtownGrouped
downtownGrouped.shape
# Out:
# (19, 202)

# %%
num_top_venues = 5

for hood in downtownGrouped['Neighborhood']:
    print("----"+hood+"----")
    temp = downtownGrouped[downtownGrouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.05
# 1              Bakery  0.04
# 2      Farmers Market  0.04
# 3         Cheese Shop  0.04
# 4  Seafood Restaurant  0.04
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3           Airport  0.07
# 4   Harbor / Marina  0.07
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.19
# 1  Italian Restaurant  0.06
# 2                Café  0.06
# 3      Sandwich Place  0.05
# 4     Bubble Tea Shop  0.03
#
#
# ----Christie----
#                 venue  freq
# 0       Grocery Store  0.22
# 1                Café  0.17
# 2                Park  0.11
# 3  Italian Restaurant  0.06
# 4               Diner  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1  Japanese Restaurant  0.05
# 2              Gay Bar  0.05
# 3           Restaurant  0.04
# 4     Sushi Restaurant  0.04
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.07
# 2           Restaurant  0.07
# 3                Hotel  0.06
# 4  American Restaurant  0.04
#
#
# ----First Canadian Place, Underground city----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.07
# 2   Restaurant  0.06
# 3        Hotel  0.04
# 4          Bar  0.03
#
#
# ----Garden District, Ryerson----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1      Clothing Store  0.08
# 2                Café  0.04
# 3      Cosmetics Shop  0.03
# 4  Italian Restaurant  0.03
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1            Aquarium  0.05
# 2                Café  0.04
# 3  Italian Restaurant  0.04
# 4               Hotel  0.04
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                            venue  freq
# 0                           Café  0.08
# 1                    Coffee Shop  0.06
# 2          Vietnamese Restaurant  0.05
# 3             Mexican Restaurant  0.05
# 4  Vegetarian / Vegan Restaurant  0.05
#
#
# ----Queen's Park, Ontario Provincial Government----
#                  venue  freq
# 0          Coffee Shop  0.25
# 1                Diner  0.06
# 2          Music Venue  0.03
# 3             Beer Bar  0.03
# 4  Fried Chicken Joint  0.03
#
#
# ----Regent Park, Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.16
# 1       Bakery  0.06
# 2          Pub  0.06
# 3         Park  0.06
# 4         Café  0.04
#
#
# ----Richmond, Adelaide, King----
#          venue  freq
# 0  Coffee Shop  0.08
# 1         Café  0.05
# 2          Gym  0.04
# 3   Restaurant  0.04
# 4        Hotel  0.03
#
#
# ----Rosedale----
#            venue  freq
# 0           Park  0.50
# 1     Playground  0.25
# 2          Trail  0.25
# 3  Movie Theater  0.00
# 4         Market  0.00
#
#
# ----St. James Town----
#                  venue  freq
# 0                 Café  0.06
# 1          Coffee Shop  0.06
# 2         Cocktail Bar  0.05
# 3  American Restaurant  0.04
# 4             Beer Bar  0.04
#
#
# ----St. James Town, Cabbagetown----
#          venue  freq
# 0  Coffee Shop  0.07
# 1   Restaurant  0.05
# 2         Café  0.05
# 3       Bakery  0.05
# 4          Pub  0.05
#
#
# ----Stn A PO Boxes----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1   Italian Restaurant  0.04
# 2           Restaurant  0.04
# 3                 Café  0.04
# 4  Japanese Restaurant  0.03
#
#
# ----Toronto Dominion Centre, Design Exchange----
#          venue  freq
# 0  Coffee Shop  0.12
# 1        Hotel  0.08
# 2         Café  0.07
# 3   Restaurant  0.05
# 4    Gastropub  0.03
#
#
# ----University of Toronto, Harbord----
#                  venue  freq
# 0                 Café  0.14
# 1   Italian Restaurant  0.06
# 2  Japanese Restaurant  0.06
# 3                  Bar  0.06
# 4            Bookstore  0.06

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = downtownGrouped['Neighborhood']

for ind in np.arange(downtownGrouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(downtownGrouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1  CN Tower, King and Spadina, Railway Lands, Har...        Airport Lounge
# 2                                 Central Bay Street           Coffee Shop
# 3                                           Christie         Grocery Store
# 4                               Church and Wellesley           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar           Cheese Shop    Seafood Restaurant
# 1       Airport Service      Airport Terminal               Airport
# 2                  Café    Italian Restaurant        Sandwich Place
# 3                  Café                  Park    Italian Restaurant
# 4   Japanese Restaurant               Gay Bar      Sushi Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Farmers Market                Bakery            Restaurant
# 1           Coffee Shop         Boat or Ferry      Sculpture Garden
# 2           Salad Place      Sushi Restaurant       Bubble Tea Shop
# 3    Athletics & Sports             Nightclub                 Diner
# 4            Restaurant                   Pub                 Hotel
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Italian Restaurant                  Café               Beer Bar
# 1              Boutique    Airport Food Court        Harbor / Marina
# 2          Burger Joint        Ice Cream Shop    Japanese Restaurant
# 3            Restaurant           Coffee Shop             Baby Store
# 4          Burger Joint                  Café            Yoga Studio

# %% [markdown]
# Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

downtownGroupedClustering = downtownGrouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(downtownGroupedClustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 4, 3, 0, 0, 0, 0, 0, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

downtownMerged = torontodf

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
downtownMerged = downtownMerged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

downtownMerged.head() # check the last columns!
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M5E  Downtown Toronto                                  Berczy Park
#
#     Latitude  Longittude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260  -79.360636               0           Coffee Shop
# 1  43.662301  -79.389494               4           Coffee Shop
# 2  43.657162  -79.378937               0           Coffee Shop
# 3  43.651494  -79.375418               0                  Café
# 4  43.644771  -79.373306               0           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Pub                Bakery                  Park
# 1                 Diner           Yoga Studio                  Café
# 2        Clothing Store                  Café        Cosmetics Shop
# 3           Coffee Shop          Cocktail Bar              Beer Bar
# 4          Cocktail Bar           Cheese Shop    Seafood Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Restaurant    Mexican Restaurant        Breakfast Spot
# 1              Beer Bar    Italian Restaurant             Juice Bar
# 2       Bubble Tea Shop   Japanese Restaurant    Italian Restaurant
# 3   American Restaurant            Restaurant                 Hotel
# 4        Farmers Market                Bakery            Restaurant
#
#        8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                       Café               Theater         Farmers Market
# 1             Sandwich Place          Burger Joint          Burrito Place
# 2  Middle Eastern Restaurant                 Diner              Bookstore
# 3           Department Store    Italian Restaurant                   Park
# 4         Italian Restaurant                  Café               Beer Bar

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(downtownMerged['Latitude'], downtownMerged['Longittude'], downtownMerged['Neighborhood'], downtownMerged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
